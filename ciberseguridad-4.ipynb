# %%
# Importar las librerias
import getpass
import random

# Diccionario para almacenar las credenciales de acceso
login_credentials = {
    'admin': 'password'
}

# Diccionario para almacenar las cuentas bloqueadas
locked_accounts = {}

def send_package():
    # Obtener del usuario el nombre del remitente, el nombre del destinatario y el peso del paquete
    sender_name = input("Enter the sender's name: ")
    recipient_name = input("Enter the recipient's name: ")
    weight = float(input("Enter the weight of the package in kg: "))

    # Generar un número de paquete aleatorio y calcular el precio del envío
    package_number = random.randint(1000, 9999)
    shipping_price = weight * 2

    # Imprimir el número de paquete y el valor a pagar
    print("Package number:", package_number)
    print("Amount to pay: $", shipping_price)

def shipping_system():
    print("Online Shipping System")
    print("----------------------")

    while True:
        if not login():
            continue

        # Mostrar el menu al usuario
        print("\nMain Menu:")
        print("1. Send a Package")
        print("2. Exit")

        # Solicitar que el usuario escoja una opción
        choice = input("Enter your choice: ")

        # Verificar si la opción del usuario es valida
        if choice == "1":
            send_package()
        elif choice == "2":
            print("Exiting...")
            break
        else:
            print("Invalid choice")

        # Verificar si el usuario quiere hacer otra operación
        another_operation = input("Do you want to perform another operation? (yes/no): ")

        if another_operation.lower() != 'yes':
            print("Closing the system...")
            break

shipping_system()
